# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# your code here


a = 2
b = 10

random_numbers = np.random.uniform(a, b, 10)

random_numbers
# Out:
# array([8.32133048, 5.71897453, 9.4137849 , 6.91612106, 6.9187354 ,
#        3.75641969, 4.59901762, 7.61130527, 8.83271131, 4.71286587])

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here

def generate_uniform(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, count)

# %%
# your code here

data1 = generate_uniform(10, 15, 100)
data2 = generate_uniform(10, 60, 1000)

# %%
plt.figure(figsize=(12, 5))

# Primer histograma
plt.subplot(1, 2, 1)
plt.hist(data1, bins=10)
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Uniform Distribution (10–15, n=100)")

# Segundo histograma
plt.subplot(1, 2, 2)
plt.hist(data2, bins=10)
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Uniform Distribution (10–60, n=1000)")

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

Son distribuciones uniformes pero difieren en el rango y el tamaño de la muestra.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here

def generate_normal(mean, std_dev, count):
    return np.random.normal(mean, std_dev, count)

# %%
# your code here

data1 = generate_normal(10, 1, 1000)
data2 = generate_normal(10, 50, 1000)

# %%
# your code here

plt.figure(figsize=(12, 5))

# Primera distribución (σ = 1)
plt.subplot(1, 2, 1)
plt.hist(data1, bins=30)
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Normal Distribution (μ=10, σ=1)")

# Segunda distribución (σ = 50)
plt.subplot(1, 2, 2)
plt.hist(data2, bins=30)
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Normal Distribution (μ=10, σ=50)")

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Your answer here
#
# La segunda distribución tiene mayor variabilidad y es más extendida.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here

df = pd.read_csv("vehicles.csv")

# %%
# your code here

fuel = df["Fuel Barrels/Year"].dropna()

plt.figure()
plt.hist(fuel, bins=30)

plt.xlabel("Fuel Barrels/Year")
plt.ylabel("Count")
plt.title("Histogram of Fuel Barrels per Year")

plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here

co2 = df["CO2 Emission Grams/Mile"].dropna()

plt.figure()
plt.hist(co2, bins=30)

plt.xlabel("CO2 Emission Grams/Mile")
plt.ylabel("Count")
plt.title("Histogram of CO2 Emission (Grams per Mile)")

plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
# your code here

mpg = df["Combined MPG"].dropna()

plt.figure()
plt.hist(mpg, bins=30)

plt.xlabel("Combined MPG")
plt.ylabel("Count")
plt.title("Histogram of Combined MPG")

plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your code here

Combined MPG es la variable que más se aproxima a una distribución normal ya que dispone de una forma más simétrica y parecida a una campana.

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here

def generate_exponential(count):
    return np.random.exponential(scale=10, size=count)

data1 = generate_exponential(10)
data2 = generate_exponential(100)

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.hist(data1, bins=100)
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Exponential Distribution (n=10, mean=10)")

plt.subplot(1,2,2)
plt.hist(data2, bins=100)
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Exponential Distribution (n=100, mean=10)")

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your code here


lam = 1/10  # lambda
x = 15

prob = 1 - math.exp(-lam * x)

prob
# Out:
# 0.7768698398515702

# %%
# your answer here 0,7769
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your code here


lam = 1/10
x = 15

prob = math.exp(-lam * x)

prob
# Out:
# 0.22313016014842982
